# %%
Customer={"name": "Amit", "balance": 5000}
if (Balance > 3000):
        print("Good Balance")
else:
        print("Low Balance")
# Out:
# Good Balance

# %%
account = ("Priya", "Savings")
if account[1] == "Savings" :
    print("Savings Account")
# Out:
# Savings Account

# %%
Customer=("Karan","Naman","Krunal")
for name in Customer:
    print(name)
# Out:
# Karan
# Naman
# Krunal

# %%
transactions = (500, -200, 1000, -700)
for Capital in transactions:
    if Capital < 200:
        print("Credit")
else:
        print("Debit")
# Out:
# Credit
# Credit
# Debit

# %%
Transaction=(6000,3000,5000,7500,3400)
for Capital in Transaction:
    if Capital>5500:
        print("Large")
    else:
        print("Small")
# Out:
# Large
# Small
# Small
# Large
# Small

# %%
Balance=10000
Amount=int(input("Enter the Debit Amount"))
if Amount<=Balance:
    print("Debit Successfull")
else:
    print("Insufficient Balance")
# Out:
# Enter the Debit Amount 7000
# Debit Successfull

# %%
Account={"Balance": 8000}
Amount=int(input("Enter the Amount"))
if Amount <= Account["Balance"]:
    Account["Balance"]=Account["Balance"] - Amount
    print("New Balance:",Account["Balance"])
else:
    print("Not enough balance")
# Out:
# Enter the Amount 4500
# New Balance: 3500

# %%
Transaction=[("Credit", 1000), ("Debit", 500)]
for payments in Transaction:
    if Transaction== "Debit":
