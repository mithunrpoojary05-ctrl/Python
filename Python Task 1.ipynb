# %%
name="Mithun R"
age=18
height=5.9
print(name,age,height)
# Out:
# Mithun R 18 5.9

# %%
person1=input("Enter the forst number:")
person2=input("Enter the second number:")
print(person1)
print(person2)
# Out:
# Enter the forst number: 10
# Enter the second number: 15
# 10
# 15

# %%
price=700
is_available= True
print(price, type(price))
print(is_available,type(is_available))
# Out:
# 700 <class 'int'>
# True <class 'bool'>

# %%
name=input("Enter your name:")
age=int(input("Enter your age:"))
print("Hello",name,"you are",age,"old")
# Out:
# Enter your name: Arjun
# Enter your age: 22
# Hello Arjun you are 22 old

# %%
num1=float(input("Enter the first number:"))
num2=float(input("Enter the second number:"))
print("Sum =",num1 + num2)
print("Difference =",num1 - num2)
print("Product =",num1 * num2)
print("Quotient =",num1 / num2)
# Out:
# Enter the first number: 12
# Enter the second number: 4
# Sum = 16.0
# Difference = 8.0
# Product = 48.0
# Quotient = 3.0

# %%
Price=float(input("Enter the price:"))
Quantity=float(input("Enter the Quantity:"))
total_cost=Price * Quantity
print("total cost",total_cost)
# Out:
# Enter the price: 200
# Enter the Quantity: 6
# total cost 1200.0

# %%
x=float(input("Enter the first number:"))
y=float(input("Enter the second number:"))
print("Addition =", x + y) 
print("Subtraction =", x - y) 
print("Multiplication =", x * y) 
print("Division =", x / y) 
print("Floor Division =", x // y) 
print("Modulus =", x % y)
print("Power =", x ** y)
# Out:
# Enter the first number: 10
# Enter the second number: 5
# Addition = 15.0
# Subtraction = 5.0
# Multiplication = 50.0
# Division = 2.0
# Floor Division = 2.0
# Modulus = 0.0
# Power = 100000.0

# %%
cost_price=1000
selling_price=1200
profit=selling_price - cost_price
print("profit",profit)
# Out:
# profit 200

# %%
cost_price=1500
selling_price=1300
loss=cost_price - selling_price
print("loss",loss)
# Out:
# loss 200

# %%
price=2000
discount_rate=20
discount=price * discount_rate/100
final_price=price-discount
print("final price",final_price)
print("discount",discount)
# Out:
# final price 1600.0
# discount 400.0

# %%
cost_price=float(input("Enter cost price"))
selling_price=float(input("Enter selling price"))
if selling_price > cost_price:
    profit=selling_price - cost_price
    profit_percent=(profit/cost_price) * 100
    print("profit",profit)
    print("profit %",profit_percent)

elif selling_price < cost_price:
    loss=cost_price - selling_price
    loss_percent=(loss/cost_price) * 100
    print("loss",loss)
    print("loss %",loss_percent)

else:
    print("no profit,no loss")
# Out:
# Enter cost price 1000
# Enter selling price 1400
# profit 400.0
# profit % 40.0

# %%
price=float(input("Enter the price"))
GST_rate=float(input("Enter the GST rate"))
GST_amount=price * GST_rate / 100
final_price=price + GST_amount
print("GST amount =",GST_amount)
print("final price =",final_price)
# Out:
# Enter the price 1000
# Enter the GST rate 18
# GST amount = 180.0
# final price = 1180.0

# %%
income=float(input("Enter the annual income"))
if income <= 500000:
    tax=0
else:
    tax=(income-500000) * 10/100
print("Tax amount =",tax)
# Out:
# Enter the annual income 600000
# Tax amount = 10000.0
