# %%
def simple_interest(p,r,t):
    simple_interest=(p*r*t)/100
    return simple_interest

# %%
def compound_interest(p,r,t):
    amount=p=(1+(r/100))**t
    compound_interest=amount-p
    return compound_interest

# %%
n=int(input("Enter the number of customers"))
for i in range(n):
    print("\n customers", i+1)
    p=int(input("Enter the principle"))
    r=int(input("Enter the rate"))
    t=int(input("Enter the time"))
    simple_interest=simple_interest(p,r,t)
    compound_interest=compound_interest(p,r,t)
    print("simple_interest", simple_interest)
    print("compound_interest",compound_interest)
# Out:
# Enter the number of customers 8
#  customers 1
# Enter the principle 2200
# Enter the rate 200
# Enter the time 2
# simple_interest 8800.0
# compound_interest 0.0
#
#  customers 2
# Enter the principle 4400
# Enter the rate 500
# Enter the time 4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 7
#       5 r=int(input("Enter the rate"))
#       6 t=int(input("Enter the time"))
# ----> 7 simple_interest=simple_interest(p,r,t)
#       8 compound_interest=compound_interest(p,r,t)
#       9 print("simple_interest", simple_interest)
#
# TypeError: 'float' object is not callable
