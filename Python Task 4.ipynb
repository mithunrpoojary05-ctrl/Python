# %%
try:
    balance=int(input("Enter the balance"))
    T=int(input("Enter the transactions"))
    transactions=[]
    for i in range(T):
        print("\n Transactions",i+1)
        try:
            amount=int(input("Enter the amount"))
            transaction_type=input("Debit ot Credit")
            transactions.append(["amount","transaction_type"])
        except ValueError:
            print("Invalid input,Enter the valied input")

    for transaction in transactions:
        amount=transaction[0]
        transaction_typr=transaction[1]

    if transaction_type.lower()=="Credit":
        balance=balance+amount
    elif transaction_type.upper()=="Debit":
        balance=balance-amount
    else:
        print("Invalid input")

    print("Final balance",balance)
except ValueError:
    print("Invalid input, Enter the valid input")
# Out:
# Enter the balance 70000
# Enter the transactions 5
#  Transactions 1
# Enter the amount 10000
# Debit ot Credit Credit
#  Transactions 2
# Enter the amount 8000
# Debit ot Credit Debit
#  Transactions 3
# Enter the amount 32000
# Debit ot Credit Debit
#  Transactions 4
# Enter the amount 10000
# Debit ot Credit Credit
#  Transactions 5
# Enter the amount 10000
# Debit ot Credit Debit
# Invalid input
# Final balance 70000
